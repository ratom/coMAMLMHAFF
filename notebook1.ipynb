# %%
# !pip install torchmeta==1.4.0

# %%
#CML

# %%
import os
import random
from PIL import Image
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from transformers import ViTModel

# -------------------------------
# BaseNet
# -------------------------------
class BaseNet(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        model_Res = models.resnet50(pretrained=True)
        self.resnet = nn.Sequential(*list(model_Res.children())[:-1])
        # Freeze everything except layer3, layer4
        for name, param in self.resnet.named_parameters():
            if not (name.startswith('layer3') or name.startswith('layer4')):
                param.requires_grad = False

        self.vit = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
        self.res_linear = nn.Linear(2048, 64)
        self.trans_linear = nn.Linear(768, 64)
        self.self_attention = nn.MultiheadAttention(embed_dim=64, num_heads=8)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, trans_b, res_b, params=None):
        device = trans_b.device
        # ResNet features
        res_features = self.resnet(res_b)
        res_features = torch.flatten(res_features, 1)
        if params is None:
            res_features = self.res_linear(res_features)
        else:
            w = params.get('res_linear.weight', self.res_linear.weight)
            b = params.get('res_linear.bias', self.res_linear.bias)
            res_features = F.linear(res_features, w.to(device), b.to(device))

        # ViT features
        vit_features = torch.mean(self.vit(trans_b).last_hidden_state, dim=1)
        if params is None:
            vit_features = self.trans_linear(vit_features)
        else:
            w = params.get('trans_linear.weight', self.trans_linear.weight)
            b = params.get('trans_linear.bias', self.trans_linear.bias)
            vit_features = F.linear(vit_features, w.to(device), b.to(device))

        # Self-attention fusion
        res_seq = res_features.unsqueeze(0)
        vit_seq = vit_features.unsqueeze(0)
        fused_seq, _ = self.self_attention(vit_seq, res_seq, vit_seq)
        fused = fused_seq.squeeze(0)

        if params is None:
            out = self.fc(fused)
        else:
            w = params.get('fc.weight', self.fc.weight)
            b = params.get('fc.bias', self.fc.bias)
            out = F.linear(fused, w.to(device), b.to(device))

        return out, fused

    def named_adaptable_parameters(self):
        return [
            ('res_linear.weight', self.res_linear.weight),
            ('res_linear.bias', self.res_linear.bias),
            ('trans_linear.weight', self.trans_linear.weight),
            ('trans_linear.bias', self.trans_linear.bias),
            ('fc.weight', self.fc.weight),
            ('fc.bias', self.fc.bias)
        ]

# -------------------------------
# CoLearner
# -------------------------------
class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch, maxpool=True):
        super().__init__()
        layers = [nn.Conv2d(in_ch, out_ch, 3, padding=1),
                  nn.BatchNorm2d(out_ch), nn.ReLU()]
        if maxpool:
            layers.append(nn.MaxPool2d(2))
        self.block = nn.Sequential(*layers)
    def forward(self, x):
        return self.block(x)

class CoLearner(nn.Module):
    def __init__(self, in_channels, out_features, hidden_size):
        super().__init__()
        self.fixed_conv1 = ConvBlock(in_channels, hidden_size, maxpool=False)
        self.fixed_conv2 = ConvBlock(hidden_size, hidden_size)
        self.fixed_cls = None
        self.hidden_size = hidden_size
        self.out_features = out_features

    def forward(self, x):
        device = x.device
        features = self.fixed_conv1(x)
        features = self.fixed_conv2(features)
        features = features.view(features.size(0), -1)
        if self.fixed_cls is None:
            self.fixed_cls = nn.Linear(features.size(1), self.out_features).to(device)
        logits = self.fixed_cls(features)
        return features, logits

# -------------------------------
# Few-Shot Dataset
# -------------------------------
class FSLCDataset(Dataset):
    def __init__(self, folder, num_ways=5, num_shots=5, num_queries=5, transform=None):
        self.num_ways = num_ways
        self.num_shots = num_shots
        self.num_queries = num_queries
        self.transform = transform or transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor()
        ])
        self.data = {}
        for cls in sorted(os.listdir(folder)):
            cls_folder = os.path.join(folder, cls)
            if not os.path.isdir(cls_folder):
                continue
            imgs = [os.path.join(cls_folder,f) for f in os.listdir(cls_folder)
                    if f.lower().endswith(('.jpg','.JPG'))]
            if len(imgs) >= self.num_shots + self.num_queries:
                self.data[cls] = imgs
        self.classes = list(self.data.keys())
        if len(self.classes) < self.num_ways:
            raise ValueError(f"Not enough eligible classes: need {self.num_ways}, got {len(self.classes)}")

    def __len__(self):
        return 1000

    def __getitem__(self, idx):
        sampled_classes = random.sample(self.classes, self.num_ways)
        support_imgs, support_labels, query_imgs, query_labels = [], [], [], []
        for i, cls in enumerate(sampled_classes):
            imgs = random.sample(self.data[cls], self.num_shots + self.num_queries)
            support_imgs.extend(imgs[:self.num_shots])
            query_imgs.extend(imgs[self.num_shots:])
            support_labels.extend([i]*self.num_shots)
            query_labels.extend([i]*self.num_queries)

        support_tensors = [self.transform(Image.open(f).convert('RGB')) for f in support_imgs]
        query_tensors = [self.transform(Image.open(f).convert('RGB')) for f in query_imgs]
        return (torch.stack(support_tensors), torch.tensor(support_labels),
                torch.stack(query_tensors), torch.tensor(query_labels))

# -------------------------------
# Accuracy
# -------------------------------
def get_accuracy(logits, targets):
    _, preds = torch.max(logits, dim=1)
    return torch.mean((preds==targets).float())

# -------------------------------
# Helper for inner-loop param adaptation
# -------------------------------
def build_adaptable_param_dict(model, device):
    return {n: p.clone().detach().to(device).requires_grad_(True) for n,p in model.named_adaptable_parameters()}

def extract_adaptable_tensors(param_dict):
    keys = ['res_linear.weight','res_linear.bias','trans_linear.weight','trans_linear.bias','fc.weight','fc.bias']
    return [param_dict[k] for k in keys]

def update_param_dict_with_grads(param_dict, grads, lr_inner=0.5):
    keys = ['res_linear.weight','res_linear.bias','trans_linear.weight','trans_linear.bias','fc.weight','fc.bias']
    new = {}
    for k,g in zip(keys,grads):
        if g is None:
            new[k] = param_dict[k]
        else:
            new[k] = (param_dict[k] - lr_inner * g).requires_grad_(True)
    return new

# -------------------------------
# Training loop
# -------------------------------
def train_fsl_model(train_folder, val_folder, num_epochs=200, device='cuda:0',
                    inner_updates=1, meta_lr=1e-4, weight_decay=1e-5,
                    early_stop_patience=10, loss_scaling=1.0, episodes_per_epoch=10):

    device = torch.device(device if torch.cuda.is_available() else 'cpu')
    base_model = BaseNet(5).to(device)
    colearner = CoLearner(3,5,64).to(device)

    optimizer_base = torch.optim.Adam(base_model.parameters(), lr=meta_lr, weight_decay=weight_decay)
    optimizer_co = torch.optim.Adam(colearner.parameters(), lr=meta_lr, weight_decay=weight_decay)

    train_dataset = FSLCDataset(train_folder)
    val_dataset = FSLCDataset(val_folder)
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=2)

    best_val_acc = 0.0
    patience_counter = 0

    for epoch in range(num_epochs):
        base_model.train()
        colearner.train()

        ep_count = 0
        pbar = tqdm(train_loader, total=min(episodes_per_epoch,len(train_loader)),
                    desc=f"Epoch {epoch+1}/{num_epochs}", leave=False)
        for support_imgs, support_labels, query_imgs, query_labels in pbar:
            if ep_count >= episodes_per_epoch:
                break
            ep_count += 1
            support_imgs, support_labels = support_imgs.squeeze(0).to(device), support_labels.squeeze(0).to(device)
            query_imgs, query_labels = query_imgs.squeeze(0).to(device), query_labels.squeeze(0).to(device)

            # Inner-loop param adaptation
            param_dict = build_adaptable_param_dict(base_model, device)
            for _ in range(inner_updates):
                support_out,_ = base_model(support_imgs, support_imgs, params=param_dict)
                inner_loss = F.cross_entropy(support_out, support_labels)
                tensors = extract_adaptable_tensors(param_dict)
                grads = torch.autograd.grad(inner_loss, tensors, create_graph=True, allow_unused=True)
                grads = [g.to(device) if g is not None else torch.zeros_like(t) for g,t in zip(grads,tensors)]
                param_dict = update_param_dict_with_grads(param_dict, grads, lr_inner=0.5)

            # Outer-loop
            query_out,_ = base_model(query_imgs, query_imgs, params=param_dict)
            _, co_logits = colearner(query_imgs)
            loss_base = F.cross_entropy(query_out, query_labels)
            loss_co = F.cross_entropy(co_logits, query_labels)

            optimizer_base.zero_grad()
            optimizer_co.zero_grad()
            (loss_base + loss_scaling*loss_co).backward()
            optimizer_base.step()
            optimizer_co.step()

        # -------------------------------
        # Validation only
        # -------------------------------
        base_model.eval()
        colearner.eval()
        val_acc = 0
        vcount = 0
        with torch.no_grad():
            for support_imgs, support_labels, query_imgs, query_labels in val_loader:
                vcount += 1
                support_imgs, support_labels = support_imgs.squeeze(0).to(device), support_labels.squeeze(0).to(device)
                query_imgs, query_labels = query_imgs.squeeze(0).to(device), query_labels.squeeze(0).to(device)
                param_dict = build_adaptable_param_dict(base_model, device)
                query_out,_ = base_model(query_imgs, query_imgs, params=param_dict)
                val_acc += get_accuracy(query_out, query_labels).item()
        val_acc /= max(1,vcount)

        print(f"Epoch {epoch+1}: ValAcc = {val_acc:.4f}")
        if val_acc > best_val_acc + 1e-6:
            best_val_acc = val_acc
            print(f"-> New best val acc: {best_val_acc:.4f}")
            torch.save(base_model.state_dict(),"best_base_model.pt")
            torch.save(colearner.state_dict(),"best_colearner.pt")
        else:
            patience_counter += 1
            if patience_counter >= early_stop_patience:
                print("Early stopping triggered.")
                break

# -------------------------------
# Run
# -------------------------------
if __name__ == '__main__':
    train_folder = '/kaggle/input/fslcattledata/cattleFSL/UNEData'
    val_folder = '/kaggle/input/fslcattledata/cattleFSL/BeefCattle_Muzzle_Individualized'
    train_fsl_model(train_folder, val_folder,
                    num_epochs=200,
                    device='cuda:0',
                    inner_updates=1,
                    meta_lr=1e-4,
                    weight_decay=1e-5,
                    early_stop_patience=10,
                    loss_scaling=0.2,
                    episodes_per_epoch=1000)
# Out:
# Epoch 1: ValAcc = 0.2037
# -> New best val acc: 0.2037
# Epoch 2: ValAcc = 0.2080
# -> New best val acc: 0.2080
# Epoch 3: ValAcc = 0.2116
# -> New best val acc: 0.2116
# Epoch 4: ValAcc = 0.2156
# -> New best val acc: 0.2156
# Epoch 5: ValAcc = 0.2192
# -> New best val acc: 0.2192
# Epoch 6: ValAcc = 0.2226
# -> New best val acc: 0.2226
# Epoch 7: ValAcc = 0.2219
# Epoch 8: ValAcc = 0.2219
# Epoch 9: ValAcc = 0.2265
# -> New best val acc: 0.2265
# Epoch 10: ValAcc = 0.2308
# -> New best val acc: 0.2308
# Epoch 11: ValAcc = 0.2341
# -> New best val acc: 0.2341
# Epoch 12: ValAcc = 0.2378
# -> New best val acc: 0.2378
# Epoch 13: ValAcc = 0.2367
# Epoch 14: ValAcc = 0.2363
# Epoch 15: ValAcc = 0.2402
# -> New best val acc: 0.2402
# Epoch 16: ValAcc = 0.2445
# -> New best val acc: 0.2445
# Epoch 17: ValAcc = 0.2481
# -> New best val acc: 0.2481
# Epoch 18: ValAcc = 0.2517
# -> New best val acc: 0.2517
# Epoch 19: ValAcc = 0.2511
# Epoch 20: ValAcc = 0.2549
# -> New best val acc: 0.2549
# Epoch 21: ValAcc = 0.2592
# -> New best val acc: 0.2592
# Epoch 22: ValAcc = 0.2636
# -> New best val acc: 0.2636
# Epoch 23: ValAcc = 0.2634
# Epoch 24: ValAcc = 0.2671
# -> New best val acc: 0.2671
# Epoch 25: ValAcc = 0.2709
# -> New best val acc: 0.2709
# Epoch 26: ValAcc = 0.2698
# Epoch 27: ValAcc = 0.2730
# -> New best val acc: 0.2730
# Epoch 28: ValAcc = 0.2762
# -> New best val acc: 0.2762
# Epoch 29: ValAcc = 0.2759
# Epoch 30: ValAcc = 0.2807
# -> New best val acc: 0.2807
# Epoch 31: ValAcc = 0.2848
# -> New best val acc: 0.2848
# Epoch 32: ValAcc = 0.2891
# -> New best val acc: 0.2891
# Epoch 33: ValAcc = 0.2933
# -> New best val acc: 0.2933
# Epoch 34: ValAcc = 0.2979
# -> New best val acc: 0.2979
# Epoch 35: ValAcc = 0.3013
# -> New best val acc: 0.3013
# Epoch 36: ValAcc = 0.3058
# -> New best val acc: 0.3058
# Epoch 37: ValAcc = 0.3096
# -> New best val acc: 0.3096
# Epoch 38: ValAcc = 0.3138
# -> New best val acc: 0.3138
# Epoch 39: ValAcc = 0.3171
# -> New best val acc: 0.3171
# Epoch 40: ValAcc = 0.3206
# -> New best val acc: 0.3206
# Epoch 41: ValAcc = 0.3245
# -> New best val acc: 0.3245
# Epoch 42: ValAcc = 0.3282
# -> New best val acc: 0.3282
# Epoch 43: ValAcc = 0.3315
# -> New best val acc: 0.3315
# Epoch 44: ValAcc = 0.3354
# -> New best val acc: 0.3354
# Epoch 45: ValAcc = 0.3345
# Epoch 46: ValAcc = 0.3337
# Epoch 47: ValAcc = 0.3382
# -> New best val acc: 0.3382
# Epoch 48: ValAcc = 0.3426
# -> New best val acc: 0.3426
# Epoch 49: ValAcc = 0.3464
# -> New best val acc: 0.3464
# Epoch 50: ValAcc = 0.3508
# -> New best val acc: 0.3508
# Epoch 51: ValAcc = 0.3555
# -> New best val acc: 0.3555
# Epoch 52: ValAcc = 0.3599
# -> New best val acc: 0.3599
# Epoch 53: ValAcc = 0.3643
# -> New best val acc: 0.3643
# Epoch 54: ValAcc = 0.3691
# -> New best val acc: 0.3691
# Epoch 55: ValAcc = 0.3686
# Epoch 56: ValAcc = 0.3727
# -> New best val acc: 0.3727
# Epoch 57: ValAcc = 0.3763
# -> New best val acc: 0.3763
# Epoch 58: ValAcc = 0.3810
# -> New best val acc: 0.3810
# Epoch 59: ValAcc = 0.3851
# -> New best val acc: 0.3851
# Epoch 60: ValAcc = 0.3889
# -> New best val acc: 0.3889
# Epoch 61: ValAcc = 0.3936
# -> New best val acc: 0.3936
# Epoch 62: ValAcc = 0.3973
# -> New best val acc: 0.3973
# Epoch 63: ValAcc = 0.4010
# -> New best val acc: 0.4010
# Epoch 64: ValAcc = 0.4048
# -> New best val acc: 0.4048
# Epoch 65: ValAcc = 0.4095
# -> New best val acc: 0.4095
# Epoch 66: ValAcc = 0.4133
# -> New best val acc: 0.4133
# Epoch 67: ValAcc = 0.4168
# -> New best val acc: 0.4168
# Epoch 68: ValAcc = 0.4205
# -> New best val acc: 0.4205
# Epoch 69: ValAcc = 0.4195
# Epoch 70: ValAcc = 0.4236
# -> New best val acc: 0.4236
# Epoch 71: ValAcc = 0.4228
# Epoch 72: ValAcc = 0.4217
# Epoch 73: ValAcc = 0.4251
# -> New best val acc: 0.4251
# Epoch 74: ValAcc = 0.4296
# -> New best val acc: 0.4296
# Epoch 75: ValAcc = 0.4338
# -> New best val acc: 0.4338
# Epoch 76: ValAcc = 0.4387
# -> New best val acc: 0.4387
# Epoch 77: ValAcc = 0.4427
# -> New best val acc: 0.4427
# Epoch 78: ValAcc = 0.4463
# -> New best val acc: 0.4463
# Epoch 79: ValAcc = 0.4454
# Epoch 80: ValAcc = 0.4490
# -> New best val acc: 0.4490
# Epoch 81: ValAcc = 0.4532
# -> New best val acc: 0.4532
# Epoch 82: ValAcc = 0.4569
# -> New best val acc: 0.4569
# Epoch 83: ValAcc = 0.4619
# -> New best val acc: 0.4619
# Epoch 84: ValAcc = 0.4659
# -> New best val acc: 0.4659
# Epoch 85: ValAcc = 0.4650
# Epoch 86: ValAcc = 0.4640
# Epoch 87: ValAcc = 0.4691
# -> New best val acc: 0.4691
# Epoch 88: ValAcc = 0.4727
# -> New best val acc: 0.4727
# Epoch 89: ValAcc = 0.4771
# -> New best val acc: 0.4771
# Epoch 90: ValAcc = 0.4767
# Epoch 91: ValAcc = 0.4809
# -> New best val acc: 0.4809
# Epoch 92: ValAcc = 0.4855
# -> New best val acc: 0.4855
# Epoch 93: ValAcc = 0.4894
# -> New best val acc: 0.4894
# Epoch 94: ValAcc = 0.4934
# -> New best val acc: 0.4934
# Epoch 95: ValAcc = 0.4970
# -> New best val acc: 0.4970
# Epoch 96: ValAcc = 0.5013
# -> New best val acc: 0.5013
# Epoch 97: ValAcc = 0.5058
# -> New best val acc: 0.5058
# Epoch 98: ValAcc = 0.5057
# Epoch 99: ValAcc = 0.5108
# -> New best val acc: 0.5108
# Epoch 100: ValAcc = 0.5104
# Epoch 101: ValAcc = 0.5146
# -> New best val acc: 0.5146
# Epoch 102: ValAcc = 0.5194
# -> New best val acc: 0.5194
# Epoch 103: ValAcc = 0.5193
# Epoch 104: ValAcc = 0.5248
# -> New best val acc: 0.5248
# Epoch 105: ValAcc = 0.5288
# -> New best val acc: 0.5288
# Epoch 106: ValAcc = 0.5327
# -> New best val acc: 0.5327
# Epoch 107: ValAcc = 0.5373
# -> New best val acc: 0.5373
# Epoch 108: ValAcc = 0.5411
# -> New best val acc: 0.5411
# Epoch 109: ValAcc = 0.5450
# -> New best val acc: 0.5450
# Epoch 110: ValAcc = 0.5503
# -> New best val acc: 0.5503
# Epoch 111: ValAcc = 0.5544
# -> New best val acc: 0.5544
# Epoch 112: ValAcc = 0.5596
# -> New best val acc: 0.5596
# Epoch 113: ValAcc = 0.5634
# -> New best val acc: 0.5634
# Epoch 114: ValAcc = 0.5675
# -> New best val acc: 0.5675
# Epoch 115: ValAcc = 0.5721
# -> New best val acc: 0.5721
# Epoch 116: ValAcc = 0.5764
# -> New best val acc: 0.5764
# Epoch 117: ValAcc = 0.5811
# -> New best val acc: 0.5811
# Epoch 118: ValAcc = 0.5849
# -> New best val acc: 0.5849
# Epoch 119: ValAcc = 0.5896
# -> New best val acc: 0.5896
# Epoch 120: ValAcc = 0.5939
# -> New best val acc: 0.5939
# Epoch 121: ValAcc = 0.5981
# -> New best val acc: 0.5981
# Epoch 122: ValAcc = 0.6029
# -> New best val acc: 0.6029
# Epoch 123: ValAcc = 0.6016
# Epoch 124: ValAcc = 0.6064
# -> New best val acc: 0.6064
# Epoch 125: ValAcc = 0.6110
# -> New best val acc: 0.6110
# Epoch 126: ValAcc = 0.6155
# -> New best val acc: 0.6155
# Epoch 127: ValAcc = 0.6197
# -> New best val acc: 0.6197
# Epoch 128: ValAcc = 0.6238
# -> New best val acc: 0.6238
# Epoch 129: ValAcc = 0.6287
# -> New best val acc: 0.6287
# Epoch 130: ValAcc = 0.6280
# Epoch 131: ValAcc = 0.6338
# -> New best val acc: 0.6338
# Epoch 132: ValAcc = 0.6383
# -> New best val acc: 0.6383
# Epoch 133: ValAcc = 0.6372
# Epoch 134: ValAcc = 0.6371
# Epoch 135: ValAcc = 0.6357
# Epoch 136: ValAcc = 0.6405
# -> New best val acc: 0.6405
# Epoch 137: ValAcc = 0.6456
# -> New best val acc: 0.6456
# Epoch 138: ValAcc = 0.6517
# -> New best val acc: 0.6517
# Epoch 139: ValAcc = 0.6505
# Epoch 140: ValAcc = 0.6567
# -> New best val acc: 0.6567
# Epoch 141: ValAcc = 0.6616
# -> New best val acc: 0.6616
# Epoch 142: ValAcc = 0.6673
# -> New best val acc: 0.6673
# Epoch 143: ValAcc = 0.6663
# Epoch 144: ValAcc = 0.6727
# -> New best val acc: 0.6727
# Epoch 145: ValAcc = 0.6788
# -> New best val acc: 0.6788
# Epoch 146: ValAcc = 0.6837
# -> New best val acc: 0.6837
# Epoch 147: ValAcc = 0.6884
# -> New best val acc: 0.6884
# Epoch 148: ValAcc = 0.6936
# -> New best val acc: 0.6936
# Epoch 149: ValAcc = 0.6921
# Epoch 150: ValAcc = 0.6978
# -> New best val acc: 0.6978
# Epoch 151: ValAcc = 0.7036
# -> New best val acc: 0.7036
# Epoch 152: ValAcc = 0.7083
# -> New best val acc: 0.7083
# Epoch 153: ValAcc = 0.7072
# Epoch 154: ValAcc = 0.7129
# -> New best val acc: 0.7129
# Epoch 155: ValAcc = 0.7185
# -> New best val acc: 0.7185
# Epoch 156: ValAcc = 0.7235
# -> New best val acc: 0.7235
# Epoch 157: ValAcc = 0.7287
# -> New best val acc: 0.7287
# Epoch 158: ValAcc = 0.7280
# Epoch 159: ValAcc = 0.7329
# -> New best val acc: 0.7329
# Epoch 160: ValAcc = 0.7397
# -> New best val acc: 0.7397
# Epoch 161: ValAcc = 0.7464
# -> New best val acc: 0.7464
# Epoch 162: ValAcc = 0.7458
# Epoch 163: ValAcc = 0.7516
# -> New best val acc: 0.7516
# Epoch 164: ValAcc = 0.7583
# -> New best val acc: 0.7583
# Epoch 165: ValAcc = 0.7642
# -> New best val acc: 0.7642
# Epoch 166: ValAcc = 0.7714
# -> New best val acc: 0.7714
# Epoch 167: ValAcc = 0.7785
# -> New best val acc: 0.7785
# Epoch 168: ValAcc = 0.7782
# Epoch 169: ValAcc = 0.7853
# -> New best val acc: 0.7853
# Epoch 170: ValAcc = 0.7839
# Epoch 171: ValAcc = 0.7897
# -> New best val acc: 0.7897
# Epoch 172: ValAcc = 0.7952
# -> New best val acc: 0.7952
# Epoch 173: ValAcc = 0.8023
# -> New best val acc: 0.8023
# Epoch 174: ValAcc = 0.8013
# Epoch 175: ValAcc = 0.8086
# -> New best val acc: 0.8086
# Epoch 176: ValAcc = 0.8083
# Epoch 177: ValAcc = 0.8154
# -> New best val acc: 0.8154
# Epoch 178: ValAcc = 0.8228
# -> New best val acc: 0.8228
# Epoch 179: ValAcc = 0.8298
# -> New best val acc: 0.8298
# Epoch 180: ValAcc = 0.8390
# -> New best val acc: 0.8390
# Epoch 181: ValAcc = 0.8375
# Epoch 182: ValAcc = 0.8443
# -> New best val acc: 0.8443
# Epoch 183: ValAcc = 0.8542
# -> New best val acc: 0.8542
# Epoch 184: ValAcc = 0.8623
# -> New best val acc: 0.8623
# Epoch 185: ValAcc = 0.8605
# Epoch 186: ValAcc = 0.8699
# -> New best val acc: 0.8699
# Epoch 187: ValAcc = 0.8788
# -> New best val acc: 0.8788
# Epoch 188: ValAcc = 0.8894
# -> New best val acc: 0.8894
# Epoch 189: ValAcc = 0.8866
# Epoch 190: ValAcc = 0.9015
# -> New best val acc: 0.9015
# Epoch 191: ValAcc = 0.9004
# Epoch 192: ValAcc = 0.9297
# -> New best val acc: 0.9297
# Epoch 193: ValAcc = 0.9297
# Epoch 194: ValAcc = 0.9297
# Epoch 195: ValAcc = 0.9297
# Epoch 196: ValAcc = 0.9297
# Epoch 197: ValAcc = 0.9297
# Epoch 198: ValAcc = 0.9297
# Epoch 199: ValAcc = 0.9297
# Epoch 200: ValAcc = 0.9297

# %%
#CCoMAML

# %%
import os
import random
from PIL import Image
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from transformers import ViTModel

# -------------------------------
# BaseNet
# -------------------------------
class BaseNet(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        model_Res = models.resnet50(pretrained=True)
        self.resnet = nn.Sequential(*list(model_Res.children())[:-1])
        # Freeze everything except layer3, layer4
        for name, param in self.resnet.named_parameters():
            if not (name.startswith('layer3') or name.startswith('layer4')):
                param.requires_grad = False

        self.vit = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
        self.res_linear = nn.Linear(2048, 64)
        self.trans_linear = nn.Linear(768, 64)
        self.self_attention = nn.MultiheadAttention(embed_dim=64, num_heads=8)
        self.fc = nn.Linear(64, num_classes)

    def forward(self, trans_b, res_b, params=None):
        device = trans_b.device
        # ResNet features
        res_features = self.resnet(res_b)
        res_features = torch.flatten(res_features, 1)
        if params is None:
            res_features = self.res_linear(res_features)
        else:
            w = params.get('res_linear.weight', self.res_linear.weight)
            b = params.get('res_linear.bias', self.res_linear.bias)
            res_features = F.linear(res_features, w.to(device), b.to(device))

        # ViT features
        vit_features = torch.mean(self.vit(trans_b).last_hidden_state, dim=1)
        if params is None:
            vit_features = self.trans_linear(vit_features)
        else:
            w = params.get('trans_linear.weight', self.trans_linear.weight)
            b = params.get('trans_linear.bias', self.trans_linear.bias)
            vit_features = F.linear(vit_features, w.to(device), b.to(device))

        # Self-attention fusion
        res_seq = res_features.unsqueeze(0)
        vit_seq = vit_features.unsqueeze(0)
        fused_seq, _ = self.self_attention(vit_seq, res_seq, vit_seq)
        fused = fused_seq.squeeze(0)

        if params is None:
            out = self.fc(fused)
        else:
            w = params.get('fc.weight', self.fc.weight)
            b = params.get('fc.bias', self.fc.bias)
            out = F.linear(fused, w.to(device), b.to(device))

        return out, fused

    def named_adaptable_parameters(self):
        return [
            ('res_linear.weight', self.res_linear.weight),
            ('res_linear.bias', self.res_linear.bias),
            ('trans_linear.weight', self.trans_linear.weight),
            ('trans_linear.bias', self.trans_linear.bias),
            ('fc.weight', self.fc.weight),
            ('fc.bias', self.fc.bias)
        ]

# -------------------------------
# CoLearner (Updated Architecture)
# -------------------------------
class CoLearner(nn.Module):
    def __init__(self, in_channels, out_features, hidden_size):
        super().__init__()
        # Two convolutional layers
        self.conv1 = nn.Conv2d(in_channels, hidden_size, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(hidden_size)
        self.relu1 = nn.ReLU()

        self.conv2 = nn.Conv2d(hidden_size, hidden_size, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(hidden_size)
        self.relu2 = nn.ReLU()

        # Adaptive average pooling
        self.adaptive_pool = nn.AdaptiveAvgPool2d((1,1))

        # Two fully connected layers
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.relu_fc = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, out_features)

    def forward(self, x):
        x = self.relu1(self.bn1(self.conv1(x)))
        x = self.relu2(self.bn2(self.conv2(x)))
        x = self.adaptive_pool(x)
        x = torch.flatten(x, 1)
        x = self.relu_fc(self.fc1(x))
        logits = self.fc2(x)
        return x, logits

# -------------------------------
# Few-Shot Dataset
# -------------------------------
class FSLCDataset(Dataset):
    def __init__(self, folder, num_ways=5, num_shots=5, num_queries=5, transform=None):
        self.num_ways = num_ways
        self.num_shots = num_shots
        self.num_queries = num_queries
        self.transform = transform or transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor()
        ])
        self.data = {}
        for cls in sorted(os.listdir(folder)):
            cls_folder = os.path.join(folder, cls)
            if not os.path.isdir(cls_folder):
                continue
            imgs = [os.path.join(cls_folder,f) for f in os.listdir(cls_folder)
                    if f.lower().endswith(('.jpg','.JPG'))]
            if len(imgs) >= self.num_shots + self.num_queries:
                self.data[cls] = imgs
        self.classes = list(self.data.keys())
        if len(self.classes) < self.num_ways:
            raise ValueError(f"Not enough eligible classes: need {self.num_ways}, got {len(self.classes)}")

    def __len__(self):
        return 1000

    def __getitem__(self, idx):
        sampled_classes = random.sample(self.classes, self.num_ways)
        support_imgs, support_labels, query_imgs, query_labels = [], [], [], []
        for i, cls in enumerate(sampled_classes):
            imgs = random.sample(self.data[cls], self.num_shots + self.num_queries)
            support_imgs.extend(imgs[:self.num_shots])
            query_imgs.extend(imgs[self.num_shots:])
            support_labels.extend([i]*self.num_shots)
            query_labels.extend([i]*self.num_queries)

        support_tensors = [self.transform(Image.open(f).convert('RGB')) for f in support_imgs]
        query_tensors = [self.transform(Image.open(f).convert('RGB')) for f in query_imgs]
        return (torch.stack(support_tensors), torch.tensor(support_labels),
                torch.stack(query_tensors), torch.tensor(query_labels))

# -------------------------------
# Accuracy
# -------------------------------
def get_accuracy(logits, targets):
    _, preds = torch.max(logits, dim=1)
    return torch.mean((preds==targets).float())

# -------------------------------
# Helper for inner-loop param adaptation
# -------------------------------
def build_adaptable_param_dict(model, device):
    return {n: p.clone().detach().to(device).requires_grad_(True) for n,p in model.named_adaptable_parameters()}

def extract_adaptable_tensors(param_dict):
    keys = ['res_linear.weight','res_linear.bias','trans_linear.weight','trans_linear.bias','fc.weight','fc.bias']
    return [param_dict[k] for k in keys]

def update_param_dict_with_grads(param_dict, grads, lr_inner=0.5):
    keys = ['res_linear.weight','res_linear.bias','trans_linear.weight','trans_linear.bias','fc.weight','fc.bias']
    new = {}
    for k,g in zip(keys,grads):
        if g is None:
            new[k] = param_dict[k]
        else:
            new[k] = (param_dict[k] - lr_inner * g).requires_grad_(True)
    return new

# -------------------------------
# Training loop
# -------------------------------
def train_fsl_model(train_folder, val_folder, num_epochs=200, device='cuda:0',
                    inner_updates=1, meta_lr=1e-4, weight_decay=1e-5,
                    early_stop_patience=10, loss_scaling=1.0, episodes_per_epoch=10):

    device = torch.device(device if torch.cuda.is_available() else 'cpu')
    base_model = BaseNet(5).to(device)
    colearner = CoLearner(3,5,64).to(device)

    optimizer_base = torch.optim.Adam(base_model.parameters(), lr=meta_lr, weight_decay=weight_decay)
    optimizer_co = torch.optim.Adam(colearner.parameters(), lr=meta_lr, weight_decay=weight_decay)

    train_dataset = FSLCDataset(train_folder)
    val_dataset = FSLCDataset(val_folder)
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, num_workers=2)
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=2)

    best_val_acc = 0.0
    patience_counter = 0

    for epoch in range(num_epochs):
        base_model.train()
        colearner.train()

        ep_count = 0
        pbar = tqdm(train_loader, total=min(episodes_per_epoch,len(train_loader)),
                    desc=f"Epoch {epoch+1}/{num_epochs}", leave=False)
        for support_imgs, support_labels, query_imgs, query_labels in pbar:
            if ep_count >= episodes_per_epoch:
                break
            ep_count += 1
            support_imgs, support_labels = support_imgs.squeeze(0).to(device), support_labels.squeeze(0).to(device)
            query_imgs, query_labels = query_imgs.squeeze(0).to(device), query_labels.squeeze(0).to(device)

            # Inner-loop param adaptation
            param_dict = build_adaptable_param_dict(base_model, device)
            for _ in range(inner_updates):
                support_out,_ = base_model(support_imgs, support_imgs, params=param_dict)
                inner_loss = F.cross_entropy(support_out, support_labels)
                tensors = extract_adaptable_tensors(param_dict)
                grads = torch.autograd.grad(inner_loss, tensors, create_graph=True, allow_unused=True)
                grads = [g.to(device) if g is not None else torch.zeros_like(t) for g,t in zip(grads,tensors)]
                param_dict = update_param_dict_with_grads(param_dict, grads, lr_inner=0.5)

            # Outer-loop
            query_out,_ = base_model(query_imgs, query_imgs, params=param_dict)
            _, co_logits = colearner(query_imgs)
            loss_base = F.cross_entropy(query_out, query_labels)
            loss_co = F.cross_entropy(co_logits, query_labels)

            optimizer_base.zero_grad()
            optimizer_co.zero_grad()
            (loss_base + loss_scaling*loss_co).backward()
            optimizer_base.step()
            optimizer_co.step()

        # -------------------------------
        # Validation only
        # -------------------------------
        base_model.eval()
        colearner.eval()
        val_acc = 0
        vcount = 0
        with torch.no_grad():
            for support_imgs, support_labels, query_imgs, query_labels in val_loader:
                vcount += 1
                support_imgs, support_labels = support_imgs.squeeze(0).to(device), support_labels.squeeze(0).to(device)
                query_imgs, query_labels = query_imgs.squeeze(0).to(device), query_labels.squeeze(0).to(device)
                param_dict = build_adaptable_param_dict(base_model, device)
                query_out,_ = base_model(query_imgs, query_imgs, params=param_dict)
                val_acc += get_accuracy(query_out, query_labels).item()
        val_acc /= max(1,vcount)

        print(f"Epoch {epoch+1}: ValAcc = {val_acc:.4f}")
        if val_acc > best_val_acc + 1e-6:
            best_val_acc = val_acc
            print(f"-> New best val acc: {best_val_acc:.4f}")
            torch.save(base_model.state_dict(),"best_base_model.pt")
            torch.save(colearner.state_dict(),"best_colearner.pt")
        else:
            patience_counter += 1
            if patience_counter >= early_stop_patience:
                print("Early stopping triggered.")
                break

# -------------------------------
# Run
# -------------------------------
if __name__ == '__main__':
    train_folder = '/kaggle/input/fslcattledata/cattleFSL/UNEData'
    val_folder = '/kaggle/input/fslcattledata/cattleFSL/BeefCattle_Muzzle_Individualized'
    train_fsl_model(train_folder, val_folder,
                    num_epochs=200,
                    device='cuda:0',
                    inner_updates=1,
                    meta_lr=1e-4,
                    weight_decay=1e-5,
                    early_stop_patience=10,
                    loss_scaling=0.2,
                    episodes_per_epoch=1000)
# Out:
# Epoch 1: ValAcc = 0.1968
# -> New best val acc: 0.1968
# Epoch 2: ValAcc = 0.2138
# -> New best val acc: 0.2138
# Epoch 3: ValAcc = 0.2282
# -> New best val acc: 0.2282
# Epoch 4: ValAcc = 0.2416
# -> New best val acc: 0.2416
# Epoch 5: ValAcc = 0.2578
# -> New best val acc: 0.2578
# Epoch 6: ValAcc = 0.2415
# Epoch 7: ValAcc = 0.2559
# Epoch 8: ValAcc = 0.2705
# -> New best val acc: 0.2705
# Epoch 9: ValAcc = 0.2540
# Epoch 10: ValAcc = 0.2625
# Epoch 11: ValAcc = 0.2810
# -> New best val acc: 0.2810
# Epoch 12: ValAcc = 0.2961
# -> New best val acc: 0.2961
# Epoch 13: ValAcc = 0.3094
# -> New best val acc: 0.3094
# Epoch 14: ValAcc = 0.3273
# -> New best val acc: 0.3273
# Epoch 15: ValAcc = 0.3205
# Epoch 16: ValAcc = 0.3045
# Epoch 17: ValAcc = 0.3118
# Epoch 18: ValAcc = 0.3305
# -> New best val acc: 0.3305
# Epoch 19: ValAcc = 0.3479
# -> New best val acc: 0.3479
# Epoch 20: ValAcc = 0.3579
# -> New best val acc: 0.3579
# Epoch 21: ValAcc = 0.3757
# -> New best val acc: 0.3757
# Epoch 22: ValAcc = 0.3883
# -> New best val acc: 0.3883
# Epoch 23: ValAcc = 0.3944
# -> New best val acc: 0.3944
# Epoch 24: ValAcc = 0.4048
# -> New best val acc: 0.4048
# Epoch 25: ValAcc = 0.4149
# -> New best val acc: 0.4149
# Epoch 26: ValAcc = 0.4068
# Epoch 27: ValAcc = 0.4204
# -> New best val acc: 0.4204
# Epoch 28: ValAcc = 0.4324
# -> New best val acc: 0.4324
# Epoch 29: ValAcc = 0.4391
# -> New best val acc: 0.4391
# Epoch 30: ValAcc = 0.4448
# -> New best val acc: 0.4448
# Epoch 31: ValAcc = 0.4586
# -> New best val acc: 0.4586
# Epoch 32: ValAcc = 0.4725
# -> New best val acc: 0.4725
# Epoch 33: ValAcc = 0.4810
# -> New best val acc: 0.4810
# Epoch 34: ValAcc = 0.4953
# -> New best val acc: 0.4953
# Epoch 35: ValAcc = 0.5078
# -> New best val acc: 0.5078
# Epoch 36: ValAcc = 0.5207
# -> New best val acc: 0.5207
# Epoch 37: ValAcc = 0.5260
# -> New best val acc: 0.5260
# Epoch 38: ValAcc = 0.5341
# -> New best val acc: 0.5341
# Epoch 39: ValAcc = 0.5428
# -> New best val acc: 0.5428
# Epoch 40: ValAcc = 0.5334
# Epoch 41: ValAcc = 0.5395
# Epoch 42: ValAcc = 0.5515
# -> New best val acc: 0.5515
# Epoch 43: ValAcc = 0.5610
# -> New best val acc: 0.5610
# Epoch 44: ValAcc = 0.5567
# Epoch 45: ValAcc = 0.5661
# -> New best val acc: 0.5661
# Epoch 46: ValAcc = 0.5771
# -> New best val acc: 0.5771
# Epoch 47: ValAcc = 0.5838
# -> New best val acc: 0.5838
# Epoch 48: ValAcc = 0.5902
# -> New best val acc: 0.5902
# Epoch 49: ValAcc = 0.5979
# -> New best val acc: 0.5979
# Epoch 50: ValAcc = 0.6047
# -> New best val acc: 0.6047
# Epoch 51: ValAcc = 0.5978
# Epoch 52: ValAcc = 0.6087
# -> New best val acc: 0.6087
# Epoch 53: ValAcc = 0.6196
# -> New best val acc: 0.6196
# Epoch 54: ValAcc = 0.6282
# -> New best val acc: 0.6282
# Epoch 55: ValAcc = 0.6345
# -> New best val acc: 0.6345
# Epoch 56: ValAcc = 0.6440
# -> New best val acc: 0.6440
# Epoch 57: ValAcc = 0.6529
# -> New best val acc: 0.6529
# Epoch 58: ValAcc = 0.6589
# -> New best val acc: 0.6589
# Epoch 59: ValAcc = 0.6627
# -> New best val acc: 0.6627
# Epoch 60: ValAcc = 0.6691
# -> New best val acc: 0.6691
# Epoch 61: ValAcc = 0.6781
# -> New best val acc: 0.6781
# Epoch 62: ValAcc = 0.6822
# -> New best val acc: 0.6822
# Epoch 63: ValAcc = 0.6895
# -> New best val acc: 0.6895
# Epoch 64: ValAcc = 0.6956
# -> New best val acc: 0.6956
# Epoch 65: ValAcc = 0.7002
# -> New best val acc: 0.7002
# Epoch 66: ValAcc = 0.7068
# -> New best val acc: 0.7068
# Epoch 67: ValAcc = 0.7010
# Epoch 68: ValAcc = 0.7050
# Epoch 69: ValAcc = 0.7121
# -> New best val acc: 0.7121
# Epoch 70: ValAcc = 0.7195
# -> New best val acc: 0.7195
# Epoch 71: ValAcc = 0.7256
# -> New best val acc: 0.7256
# Epoch 72: ValAcc = 0.7303
# -> New best val acc: 0.7303
# Epoch 73: ValAcc = 0.7352
# -> New best val acc: 0.7352
# Epoch 74: ValAcc = 0.7390
# -> New best val acc: 0.7390
# Epoch 75: ValAcc = 0.7425
# -> New best val acc: 0.7425
# Epoch 76: ValAcc = 0.7470
# -> New best val acc: 0.7470
# Epoch 77: ValAcc = 0.7538
# -> New best val acc: 0.7538
# Epoch 78: ValAcc = 0.7590
# -> New best val acc: 0.7590
# Epoch 79: ValAcc = 0.7641
# -> New best val acc: 0.7641
# Epoch 80: ValAcc = 0.7683
# -> New best val acc: 0.7683
# Epoch 81: ValAcc = 0.7722
# -> New best val acc: 0.7722
# Epoch 82: ValAcc = 0.7750
# -> New best val acc: 0.7750
# Epoch 83: ValAcc = 0.7779
# -> New best val acc: 0.7779
# Epoch 84: ValAcc = 0.7800
# -> New best val acc: 0.7800
# Epoch 85: ValAcc = 0.7859
# -> New best val acc: 0.7859
# Epoch 86: ValAcc = 0.7893
# -> New best val acc: 0.7893
# Epoch 87: ValAcc = 0.7923
# -> New best val acc: 0.7923
# Epoch 88: ValAcc = 0.7945
# -> New best val acc: 0.7945
# Epoch 89: ValAcc = 0.7996
# -> New best val acc: 0.7996
# Epoch 90: ValAcc = 0.8038
# -> New best val acc: 0.8038
# Epoch 91: ValAcc = 0.8085
# -> New best val acc: 0.8085
# Epoch 92: ValAcc = 0.8122
# -> New best val acc: 0.8122
# Epoch 93: ValAcc = 0.8172
# -> New best val acc: 0.8172
# Epoch 94: ValAcc = 0.8211
# -> New best val acc: 0.8211
# Epoch 95: ValAcc = 0.8253
# -> New best val acc: 0.8253
# Epoch 96: ValAcc = 0.8211
# Epoch 97: ValAcc = 0.8244
# Epoch 98: ValAcc = 0.8260
# -> New best val acc: 0.8260
# Epoch 99: ValAcc = 0.8277
# -> New best val acc: 0.8277
# Epoch 100: ValAcc = 0.8296
# -> New best val acc: 0.8296
# Epoch 101: ValAcc = 0.8321
# -> New best val acc: 0.8321
# Epoch 102: ValAcc = 0.8364
# -> New best val acc: 0.8364
# Epoch 103: ValAcc = 0.8402
# -> New best val acc: 0.8402
# Epoch 104: ValAcc = 0.8439
# -> New best val acc: 0.8439
# Epoch 105: ValAcc = 0.8464
# -> New best val acc: 0.8464
# Epoch 106: ValAcc = 0.8480
# -> New best val acc: 0.8480
# Epoch 107: ValAcc = 0.8496
# -> New best val acc: 0.8496
# Epoch 108: ValAcc = 0.8530
# -> New best val acc: 0.8530
# Epoch 109: ValAcc = 0.8552
# -> New best val acc: 0.8552
# Epoch 110: ValAcc = 0.8587
# -> New best val acc: 0.8587
# Epoch 111: ValAcc = 0.8599
# -> New best val acc: 0.8599
# Epoch 112: ValAcc = 0.8633
# -> New best val acc: 0.8633
# Epoch 113: ValAcc = 0.8657
# -> New best val acc: 0.8657
# Epoch 114: ValAcc = 0.8679
# -> New best val acc: 0.8679
# Epoch 115: ValAcc = 0.8649
# Epoch 116: ValAcc = 0.8617
# Epoch 117: ValAcc = 0.8650
# Epoch 118: ValAcc = 0.8630
# Epoch 119: ValAcc = 0.8654
# Epoch 120: ValAcc = 0.8668
# Epoch 121: ValAcc = 0.8681
# -> New best val acc: 0.8681
# Epoch 122: ValAcc = 0.8700
# -> New best val acc: 0.8700
# Epoch 123: ValAcc = 0.8669
# Epoch 124: ValAcc = 0.8697
# Epoch 125: ValAcc = 0.8711
# -> New best val acc: 0.8711
# Epoch 126: ValAcc = 0.8724
# -> New best val acc: 0.8724
# Epoch 127: ValAcc = 0.8737
# -> New best val acc: 0.8737
# Epoch 128: ValAcc = 0.8717
# Epoch 129: ValAcc = 0.8744
# -> New best val acc: 0.8744
# Epoch 130: ValAcc = 0.8755
# -> New best val acc: 0.8755
# Epoch 131: ValAcc = 0.8776
# -> New best val acc: 0.8776
# Epoch 132: ValAcc = 0.8802
# -> New best val acc: 0.8802
# Epoch 133: ValAcc = 0.8820
# -> New best val acc: 0.8820
# Epoch 134: ValAcc = 0.8837
# -> New best val acc: 0.8837
# Epoch 135: ValAcc = 0.8861
# -> New best val acc: 0.8861
# Epoch 136: ValAcc = 0.8876
# -> New best val acc: 0.8876
# Epoch 137: ValAcc = 0.8893
# -> New best val acc: 0.8893
# Epoch 138: ValAcc = 0.8918
# -> New best val acc: 0.8918
# Epoch 139: ValAcc = 0.8933
# -> New best val acc: 0.8933
# Epoch 140: ValAcc = 0.8946
# -> New best val acc: 0.8946
# Epoch 141: ValAcc = 0.8962
# -> New best val acc: 0.8962
# Epoch 142: ValAcc = 0.8972
# -> New best val acc: 0.8972
# Epoch 143: ValAcc = 0.8953
# Epoch 144: ValAcc = 0.8933
# Epoch 145: ValAcc = 0.8945
# Epoch 146: ValAcc = 0.8970
# Epoch 147: ValAcc = 0.8994
# -> New best val acc: 0.8994
# Epoch 148: ValAcc = 0.8976
# Epoch 149: ValAcc = 0.8998
# -> New best val acc: 0.8998
# Epoch 150: ValAcc = 0.9019
# -> New best val acc: 0.9019
# Epoch 151: ValAcc = 0.9036
# -> New best val acc: 0.9036
# Epoch 152: ValAcc = 0.9047
# -> New best val acc: 0.9047
# Epoch 153: ValAcc = 0.9065
# -> New best val acc: 0.9065
# Epoch 154: ValAcc = 0.9075
# -> New best val acc: 0.9075
# Epoch 155: ValAcc = 0.9091
# -> New best val acc: 0.9091
# Epoch 156: ValAcc = 0.9112
# -> New best val acc: 0.9112
# Epoch 157: ValAcc = 0.9131
# -> New best val acc: 0.9131
# Epoch 158: ValAcc = 0.9141
# -> New best val acc: 0.9141
# Epoch 159: ValAcc = 0.9161
# -> New best val acc: 0.9161
# Epoch 160: ValAcc = 0.9172
# -> New best val acc: 0.9172
# Epoch 161: ValAcc = 0.9163
# Epoch 162: ValAcc = 0.9174
# -> New best val acc: 0.9174
# Epoch 163: ValAcc = 0.9182
# -> New best val acc: 0.9182
# Epoch 164: ValAcc = 0.9192
# -> New best val acc: 0.9192
# Epoch 165: ValAcc = 0.9202
# -> New best val acc: 0.9202
# Epoch 166: ValAcc = 0.9217
# -> New best val acc: 0.9217
# Epoch 167: ValAcc = 0.9224
# -> New best val acc: 0.9224
# Epoch 168: ValAcc = 0.9234
# -> New best val acc: 0.9234
# Epoch 169: ValAcc = 0.9248
# -> New best val acc: 0.9248
# Epoch 170: ValAcc = 0.9263
# -> New best val acc: 0.9263
# Epoch 171: ValAcc = 0.9273
# -> New best val acc: 0.9273
# Epoch 172: ValAcc = 0.9279
# -> New best val acc: 0.9279
# Epoch 173: ValAcc = 0.9285
# -> New best val acc: 0.9285
# Epoch 174: ValAcc = 0.9295
# -> New best val acc: 0.9295
# Epoch 175: ValAcc = 0.9307
# -> New best val acc: 0.9307
# Epoch 176: ValAcc = 0.9317
# -> New best val acc: 0.9317
# Epoch 177: ValAcc = 0.9325
# -> New best val acc: 0.9325
# Epoch 178: ValAcc = 0.9337
# -> New best val acc: 0.9337
# Epoch 179: ValAcc = 0.9350
# -> New best val acc: 0.9350
# Epoch 180: ValAcc = 0.9356
# -> New best val acc: 0.9356
# Epoch 181: ValAcc = 0.9361
# -> New best val acc: 0.9361
# Epoch 182: ValAcc = 0.9810
# -> New best val acc: 0.9810
# Epoch 183: ValAcc = 0.9810
# Epoch 184: ValAcc = 0.9810
# Epoch 185: ValAcc = 0.9810
# Epoch 186: ValAcc = 0.9810
# Epoch 187: ValAcc = 0.9810
# Epoch 188: ValAcc = 0.9810
# Epoch 189: ValAcc = 0.9810
# Epoch 190: ValAcc = 0.9810
# Epoch 191: ValAcc = 0.9810
# Epoch 192: ValAcc = 0.9810
# Early stopping triggered.
